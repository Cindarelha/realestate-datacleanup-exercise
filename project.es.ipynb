# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de fotocasa, el cual es uno de los sitios mas populares de bienes raíces en España. Por favor no hagas estos (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa mas cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa mas cara en el todo el dataset? (★☆☆)
#
# Imprime la direccion y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
import pandas as pd

# Listar los nombres de las columnas en el dataset
columnas = df.columns.tolist()
print(columnas)
# Obtener el número de filas en el dataset
num_filas = df.shape[0]
print(f"El dataset tiene {num_filas} filas.")

# Encontrar la casa más cara
casa_mas_cara = df.loc[df['price'].idxmax()]

# Mostrar la información de la casa más cara
print("La casa más cara es:")
print(casa_mas_cara)
# Out:
# ['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name', 'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface', 'price', 'date', 'description', 'address', 'country', 'level1', 'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8', 'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id', 'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy', 'latitude', 'longitude', 'zipCode', 'customZone']
# El dataset tiene 15335 filas.
# La casa más cara es:
# Unnamed: 0                                                      13111
# id_realEstates                                              132042636
# isNew                                                           False
# realEstate_name                            engel volkers torrelodones
# phone_realEstate                                          911798512.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/vi...
# ...

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa mas barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# Encontrar la casa más cara
casa_mas_barata = df.loc[df['price'].idxmin()]

# Mostrar la información de la casa más cara
print("La casa más barata es:")
print(casa_mas_barata)
# Out:
# La casa más barata es:
# Unnamed: 0                                                        367
# id_realEstates                                              153637952
# isNew                                                           False
# realEstate_name                                                esalje
# phone_realEstate                                          912786497.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             4.0
# bathrooms                                                         4.0
# surface                                                         262.0
# price                                                               0
# date                                      2019-12-28T18:52:25.965658Z
# description         ESALJE vende amplio pareado de 268 m2. distrib...
# address                                                         Parla
# ...

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa mas grande y la mas pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el area de las casas seleccionadas. Por ejemplo:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# Encontrar la casa más grande y la más pequeña
casa_mas_grande = df.loc[df['surface'].idxmax()]
casa_mas_pequena = df.loc[df['surface'].idxmin()]

# Mostrar la información de las casas
print(f"La casa mas grande está en {casa_mas_grande['address']} y su superficie es  {casa_mas_grande['surface']} metros")
print(f"La casa mas pequeña está en {casa_mas_pequena['address']} y su superficie es  {casa_mas_pequena['surface']} metros")
# Out:
# La casa mas grande está en Sevilla la Nueva y su superficie es  249000.0 metros
# La casa mas pequeña está en Calle Amparo,  Madrid Capital y su superficie es  15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# Obtener todas las poblaciones únicas en la columna 'level5'
poblaciones = df['level5'].unique()

# Número de poblaciones
num_poblaciones = len(poblaciones)
print(f"El dataset contiene {num_poblaciones} poblaciones.")

# Imprimir los nombres de las poblaciones separados por coma
print(", ".join(poblaciones))
# Out:
# El dataset contiene 168 poblaciones.
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El data set contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`true` o `fase`) seguido de la fila/columna que contiene el NAs.

# %%
# Verificar si hay valores NAs en el dataset
hay_NAs = df.isnull().values.any()

# Si hay valores NAs, encontrar las filas y columnas que los contienen
if hay_NAs:
    # Obtener las filas y columnas que contienen NAs
    filas_columnas_na = df[df.isnull().any(axis=1)]
    print("True")
    print("Filas y columnas que contienen NAs:")
    for index, row in filas_columnas_na.iterrows():
        columnas_na = row.index[row.isnull()].tolist()
        print(f"Fila {index}, Columnas: {', '.join(columnas_na)}")
else:
    print("False")
# Out:
# True
# Filas y columnas que contienen NAs:
# Fila 0, Columnas: level6, level8, zipCode, customZone
# Fila 1, Columnas: surface, level6, level8, zipCode, customZone
# Fila 2, Columnas: level6, level8, zipCode, customZone
# Fila 3, Columnas: level6, level8, zipCode, customZone
# Fila 4, Columnas: level6, level8, zipCode, customZone
# Fila 5, Columnas: level6, level8, zipCode, customZone
# Fila 6, Columnas: level6, level8, zipCode, customZone
# Fila 7, Columnas: level6, level8, zipCode, customZone
# Fila 8, Columnas: level6, level8, zipCode, customZone
# Fila 9, Columnas: phone_realEstate, level4, level6, zipCode, customZone
# Fila 10, Columnas: level4, level6, zipCode, customZone
# Fila 11, Columnas: level6, level8, zipCode, customZone
# Fila 12, Columnas: level6, level8, zipCode, customZone
# Fila 13, Columnas: level6, level8, zipCode, customZone
# Fila 14, Columnas: level6, level8, zipCode, customZone
# Fila 15, Columnas: level4, level6, zipCode, customZone
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del data set, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# Guardar las dimensiones del DataFrame original
dimensiones_originales = df.shape

# Eliminar las filas que contienen valores NA
df_sin_na = df.dropna()

# Guardar las dimensiones del DataFrame después de eliminar los NAs
dimensiones_sin_na = df_sin_na.shape

# Imprimir la comparación de las dimensiones
print(f"Dimensiones del DataFrame original: {dimensiones_originales}")
print(f"Dimensiones del DataFrame después de eliminar NAs: {dimensiones_sin_na}")
# Out:
# Dimensiones del DataFrame original: (15335, 37)
# Dimensiones del DataFrame después de eliminar NAs: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido

# %%
# Filtrar el DataFrame por la población "Arroyomolinos (Madrid)"
arroyomolinos_df = df[df['level5'] == 'Arroyomolinos (Madrid)']

# Calcular la media de la columna 'price' en esta población
media_precio_arroyomolinos = arroyomolinos_df['price'].mean()

# Imprimir el valor obtenido
print(f"La media de precios en la población de 'Arroyomolinos (Madrid)' es: {media_precio_arroyomolinos}")
# Out:
# La media de precios en la población de 'Arroyomolinos (Madrid)' es: 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

# Filtrar el DataFrame por la población "Arroyomolinos (Madrid)"
arroyomolinos_df = df[df['level5'] == 'Arroyomolinos (Madrid)']

# Crear el histograma de los precios
plt.figure(figsize=(10, 5))
plt.hist(arroyomolinos_df['price'], bins=20, edgecolor='black')
plt.title('Histograma de Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en este celda y elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿ Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedio y escribe una conclusion acerca de ellos

# %%
#Filtrar el DataFrame por las poblaciones "Valdemorillo" y "Galapagar"
valdemorillo_df = df[df['level5'] == 'Valdemorillo']
galapagar_df = df[df['level5'] == 'Galapagar']

# Calcular la media de la columna 'price' en cada población
media_precio_valdemorillo = valdemorillo_df['price'].mean()
media_precio_galapagar = galapagar_df['price'].mean()

# Imprimir los valores obtenidos
print(f"La media de precios en Valdemorillo es: {media_precio_valdemorillo}")
print(f"La media de precios en Galapagar es: {media_precio_galapagar}")

# Comparar y escribir una conclusión
if media_precio_valdemorillo == media_precio_galapagar:
    print("Los precios promedios en Valdemorillo y Galapagar son iguales.")
else:
    print("Los precios promedios en Valdemorillo y Galapagar no son iguales.")
# Out:
# La media de precios en Valdemorillo es: 363860.2931034483
# La media de precios en Galapagar es: 360063.20238095237
# Los precios promedios en Valdemorillo y Galapagar no son iguales.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (price/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio y escribe una conclusion acerca de ellos.
#
# Pista: Crea una nueva columna llamada `pps` (price per square) y luego analiza los valore.s

# %%
# Crear la nueva columna 'pps' (price per square)
df['pps'] = df['price'] / df['surface']

# Filtrar el DataFrame por las poblaciones "Valdemorillo" y "Galapagar"
valdemorillo_df = df[df['level5'] == 'Valdemorillo']
galapagar_df = df[df['level5'] == 'Galapagar']

# Calcular la media de la columna 'pps' en cada población
media_pps_valdemorillo = valdemorillo_df['pps'].mean()
media_pps_galapagar = galapagar_df['pps'].mean()

# Imprimir los valores obtenidos
print(f"La media de precio por metro cuadrado en Valdemorillo es: {media_pps_valdemorillo}")
print(f"La media de precio por metro cuadrado en Galapagar es: {media_pps_galapagar}")

if media_pps_valdemorillo == media_pps_galapagar:
    print("Los precios promedios por metro cuadrado en Valdemorillo y Galapagar son iguales.")
else:
    print("Los precios promedios por metro cuadrado en Valdemorillo y Galapagar no son iguales.")
# Out:
# La media de precio por metro cuadrado en Valdemorillo es: 1317.9502109024986
# La media de precio por metro cuadrado en Galapagar es: 1606.3240303094024
# Los precios promedios por metro cuadrado en Valdemorillo y Galapagar no son iguales.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusion al respecto.

# %%
# Crear el gráfico de dispersión

plt.figure(figsize=(10,5))
plt.scatter(x=df['price'],y=df['surface'],color="blue")
plt.xlabel('Precio', fontsize=12)
plt.ylabel('Superficie (m2)', fontsize=12)
plt.grid(True)

# %% [markdown]
# #Conclusión: Se observan valores atípicos o "Outliers" . Creo que para sacar una gráfica y poder tener buena información habria que quitar los outliers primero y despues plotear... ??**

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# Contar el número de agencias de bienes raíces distintas
num_agencias = df['realEstate_name'].nunique()

# Imprimir el valor obtenido
print(f"El dataset contiene {num_agencias} agencias de bienes raíces distintas.")
# Out:
# El dataset contiene 1821 agencias de bienes raíces distintas.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# Contar el número de casas en cada población
poblacion_casas = df['level5'].value_counts()

# Obtener la población con la mayor cantidad de casas
poblacion_mayor_cantidad = poblacion_casas.idxmax()
cantidad_casas = poblacion_casas.max()

# Imprimir la población y el número de casas
print(f"La población con la mayor cantidad de casas es: {poblacion_mayor_cantidad}")
print(f"Número de casas en {poblacion_mayor_cantidad}: {cantidad_casas}")
# Out:
# La población con la mayor cantidad de casas es:  Madrid Capital
# Número de casas en  Madrid Capital: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Has un subconjunto del Dataframe original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Pista: Filtra el Dataframe original usando la columna `level5` y la función `isin`

# %%
# Definir las poblaciones del "cinturón sur" de Madrid
poblaciones_cinturon_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Filtrar el DataFrame original usando la columna `level5` y la función `isin`
df_cinturon_sur = df[df['level5'].isin(poblaciones_cinturon_sur)]

# Mostrar el subconjunto filtrado
print(df_cinturon_sur.head())

# Contar el número de filas para cada población
conteo_poblaciones = df_cinturon_sur['level5'].value_counts()
print(conteo_poblaciones)
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barra de la media de los precios y explica lo que observas (debes usar el subconjunto obtenido de la pregunta 14) (★★★)
#
# Imprima un gráfico de barra de la media de precios y escriba en la celda Markdown un breve análisis del sector.

# %%
# Calcular la media de los precios para cada población
media_precios = df_cinturon_sur.groupby('level5')['price'].mean()

# Crear el gráfico de barras de la media de los precios usando plt.bar
plt.figure(figsize=(10, 6))
plt.bar(media_precios.index, media_precios.values, color='blue')

plt.title('Media de Precios de Viviendas en el Cinturón Sur de Madrid', fontsize=15)
plt.xlabel('Población', fontsize=12)
plt.ylabel('Media de Precio (EUR )', fontsize=12)
plt.grid(axis='y', alpha=0.7)
plt.show()

# %% [markdown]
# # Análisis: Se puede observar que la media de los precios en getafe es superior a la media en fuenlabrada. Alcorcón y Leganés muestran medias parecidas, y en lineas generales, los precios oscilan entre los 175k y los 250k.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza dela muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Imprime ambos valores por  cada variable.

# %%
# Calcular la media y la varianza para las variables: precio, habitaciones, superficie y baños
variables = ['price', 'rooms', 'surface', 'bathrooms']
estadisticas = {}

for variable in variables:
    media = df_cinturon_sur[variable].mean()
    varianza = df_cinturon_sur[variable].var()
    estadisticas[variable] = {'media': media, 'varianza': varianza}

# Imprimir los valores de media y varianza por cada variable
for variable, stats in estadisticas.items():
    print(f"Variable: {variable}")
    print(f"Media: {stats['media']}")
    print(f"Varianza: {stats['varianza']}\n")
# Out:
# Variable: price
# Media: 223094.48070562293
# Varianza: 14921367508.04902
#
# Variable: rooms
# Media: 3.0177383592017737
# Varianza: 0.7188858892927542
#
# Variable: surface
# Media: 111.75222363405337
# Varianza: 4263.051760316337
#
# Variable: bathrooms
# Media: 1.633221850613155
# Varianza: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# Encuentra la casa mas cara de cada población
casas_mas_caras = df_cinturon_sur.loc[df_cinturon_sur.groupby('level5')['price'].idxmax()]

# Imprimir
for index, row in casas_mas_caras.iterrows():
    print(f"La casa más cara {row['level5']} esta localizada en {row['address']} co n un precio de {row['price']} EUR.")
# Out:
# La casa más cara Alcorcón esta localizada en Alcorcón co n un precio de 950000 EUR.
# La casa más cara Fuenlabrada esta localizada en Calle de Paulo Freire, 5, Fuenlabrada co n un precio de 490000 EUR.
# La casa más cara Getafe esta localizada en Getafe co n un precio de 1050000 EUR.
# La casa más cara Leganés esta localizada en Avenida Reina Sofía, Leganés co n un precio de 650000 EUR.

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# Normalizar restando la media y dividiendo por la desviación estandar
df_cinturon_sur['normalized_price'] = df_cinturon_sur.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# Plotear los histogramas normalizados
plt.figure(figsize=(10, 5))

for population in poblaciones_cinturon_sur:
    subset = df_cinturon_sur[df_cinturon_sur['level5'] == population]
    plt.hist(subset['normalized_price'], bins=20, alpha=0.5, label=population)

plt.title('Normalized Price para las poblaciones en el Cinturón Sur de Madrid')
plt.xlabel('Normalized Price')
plt.ylabel('Frecuecia')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_456/2416140681.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cinturon_sur['normalized_price'] = df_cinturon_sur.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# # Al normalizarlo nos permite comparar en un orden de escala similar los precios de cada población. Se puede observar la distribución y su parecido con respecto a las diferentes poblaciones.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# Nueva columna en el df "pps" (price per square meter)
df_cinturon_sur.loc[:, 'pps'] = df_cinturon_sur['price'] / df_cinturon_sur['surface']

# Filtra el df por ciudades "Getafe" y "Alcorcón"
df_getafe = df_cinturon_sur[df_cinturon_sur['level5'] == 'Getafe']
df_alcorcon = df_cinturon_sur[df_cinturon_sur['level5'] == 'Alcorcón']

# Calcula media y varianza 'pps' 
mean_pps_getafe = df_getafe['pps'].mean()
mean_pps_alcorcon = df_alcorcon['pps'].mean()
var_pps_getafe = df_getafe['pps'].var()
var_pps_alcorcon = df_alcorcon['pps'].var()

# Imprimir
print(f"Getafe - Media del precio por metro cuadrado: {mean_pps_getafe:.2f} EUR/m², Varianza: {var_pps_getafe:.2f}")
print(f"Alcorcón - Media del precio por metro cuadrado: {mean_pps_alcorcon:.2f} EUR/m², Varianza: {var_pps_alcorcon:.2f}")
# Out:
# Getafe - Media del precio por metro cuadrado: 2066.31 EUR/m², Varianza: 550375.11
# Alcorcón - Media del precio por metro cuadrado: 2239.30 EUR/m², Varianza: 291547.65

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# Subplots para cada población
fig, axs = plt.subplots(2, 2, figsize=(14, 10), sharex=True, sharey=True)

# Definir los elementos de población
poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
axs = axs.flatten()

for ax, population in zip(axs, poblaciones):
    subset = df_cinturon_sur[df_cinturon_sur['level5'] == population]
    ax.scatter(subset['surface'], subset['pps'], alpha=0.6, edgecolor='w', color='blue')
    ax.set_title(f'{population}')
    ax.set_xlabel('Superficie (m²)')
    ax.set_ylabel('Precio por m² (EUR/m²)')
    ax.grid(True)

plt.suptitle('Scatter Plots of Price per Square Meter for Different Populations', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón ur de Madrid por color d cada población (debes usar el subconjunto obtenido en la pregunta 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar u código simple que transforme las columnas de coordenadas en un diccionario de python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, Circle
# Definir las poblaciones del "cinturón sur" de Madrid
poblaciones_cinturon_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Filtrar el DataFrame original usando la columna `level5` y la función `isin`
df_cinturon_sur = df[df['level5'].isin(poblaciones_cinturon_sur)]

# Crear un diccionario de coordenadas por población
coordenadas_por_poblacion = {poblacion: {'latitud': [], 'longitud': []} for poblacion in poblaciones_cinturon_sur}

# Reemplazar comas por puntos en las columnas de coordenadas y convertir a float

df_cinturon_sur.loc[:, 'latitude'] = df_cinturon_sur['latitude'].str.replace(',', '.').astype(float)
df_cinturon_sur.loc[:, 'longitude'] = df_cinturon_sur['longitude'].str.replace(',', '.').astype(float)

# Rellenar el diccionario con los datos de las coordenadas
for poblacion in poblaciones_cinturon_sur:
    subset = df_cinturon_sur[df_cinturon_sur['level5'] == poblacion]
    coordenadas_por_poblacion[poblacion]['latitud'] = subset['latitude'].tolist()
    coordenadas_por_poblacion[poblacion]['longitud'] = subset['longitude'].tolist()

# Mapa centrado en (60 grados latitud et -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)


# Definir los colores para cada población
colores = {
    'Fuenlabrada': 'red',
    'Leganés': 'blue',
    'Getafe': 'green',
    'Alcorcón': 'purple'
}

# Agregar los puntos de cada población al mapa
for poblacion, coords in coordenadas_por_poblacion.items():
    for lat, lon in zip(coords['latitud'], coords['longitud']):
        circle = Circle(
            location=(lat, lon),
            radius=50,
            color=colores[poblacion],
            fill=True,
            fill_color=colores[poblacion],
            fill_opacity=0.6,
        )
        map.add_layer(circle)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
